# %% [markdown]
# # Loading the required libraries

# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
fifa=pd.read_csv('players_22.csv')

# %%
fifa.head()
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1     188545  https://sofifa.com/player/188545/robert-lewand...
# 2      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 3     190871  https://sofifa.com/player/190871/neymar-da-sil...
# 4     192985  https://sofifa.com/player/192985/kevin-de-bruy...
#
#           short_name                            long_name player_positions  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini       RW, ST, CF
# 1     R. Lewandowski                   Robert Lewandowski               ST
# 2  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro           ST, LW
# 3          Neymar Jr        Neymar da Silva Santos Júnior          LW, CAM
# 4       K. De Bruyne                      Kevin De Bruyne          CM, CAM
#
#    overall  potential    value_eur  wage_eur  age  ...   lcb    cb   rcb  \
# ...

# %% [markdown]
# # Number of Columns in dataset

# %%
for col in fifa.columns:
    print(col)
# Out:
# sofifa_id
# player_url
# short_name
# long_name
# player_positions
# overall
# potential
# value_eur
# wage_eur
# age
# dob
# height_cm
# weight_kg
# club_team_id
# club_name
# league_name
# league_level
# club_position
# club_jersey_number
# club_loaned_from
# club_joined
# club_contract_valid_until
# nationality_id
# nationality_name
# nation_team_id
# nation_position
# nation_jersey_number
# preferred_foot
# weak_foot
# skill_moves
# international_reputation
# work_rate
# body_type
# real_face
# release_clause_eur
# player_tags
# player_traits
# pace
# shooting
# passing
# dribbling
# defending
# physic
# attacking_crossing
# attacking_finishing
# attacking_heading_accuracy
# attacking_short_passing
# attacking_volleys
# skill_dribbling
# skill_curve
# skill_fk_accuracy
# skill_long_passing
# skill_ball_control
# movement_acceleration
# movement_sprint_speed
# movement_agility
# movement_reactions
# movement_balance
# power_shot_power
# power_jumping
# power_stamina
# ...

# %%
fifa.shape
# Out:
# (19239, 110)

# %%
fifa['nationality_name'].value_counts()
# Out:
# England             1719
# Germany             1214
# Spain               1086
# France               980
# Argentina            960
#                     ...
# Ethiopia               1
# Papua New Guinea       1
# Kyrgyzstan             1
# Guam                   1
# Indonesia              1
# Name: nationality_name, Length: 163, dtype: int64

# %% [markdown]
# # Top 10 Countries with most players

# %%
fifa['nationality_name'].value_counts()[0:10]
# Out:
# England          1719
# Germany          1214
# Spain            1086
# France            980
# Argentina         960
# Brazil            897
# Japan             546
# Netherlands       439
# United States     413
# Poland            403
# Name: nationality_name, dtype: int64

# %% [markdown]
# # Top 5 countries with most players

# %%
fifa['nationality_name'].value_counts()[0:5].keys()
# Out:
# Index(['England', 'Germany', 'Spain', 'France', 'Argentina'], dtype='object')

# %% [markdown]
# # Bar graph for top 5 countries with most players

# %%
plt.figure(figsize=(7,7))
plt.bar(list(fifa['nationality_name'].value_counts()[0:5].keys()),list(fifa['nationality_name'].value_counts()[0:5]),color='g')
plt.show()

# %%
player_salary=fifa[['short_name','wage_eur']]

# %% [markdown]
# # 5 players with their salaries

# %%
player_salary.head()
# Out:
#           short_name  wage_eur
# 0           L. Messi  320000.0
# 1     R. Lewandowski  270000.0
# 2  Cristiano Ronaldo  270000.0
# 3          Neymar Jr  270000.0
# 4       K. De Bruyne  350000.0

# %%
player_salary=player_salary.sort_values(by=['wage_eur'],ascending=False)

# %% [markdown]
# # Top 5 players with their salaries in descending order

# %%
player_salary.head()
# Out:
#       short_name  wage_eur
# 4   K. De Bruyne  350000.0
# 11    K. Benzema  350000.0
# 0       L. Messi  320000.0
# 14      Casemiro  310000.0
# 24      T. Kroos  310000.0

# %% [markdown]
# # Bar graph for top 5 players with their salaries in descending order

# %%
plt.bar(list(player_salary['short_name'])[0:5],list(player_salary['wage_eur'])[0:5],color=['blue','green','red','yellow','pink'])
plt.show()

# %% [markdown]
# # Germany

# %%
Germany=fifa[fifa['nationality_name']=='Germany']
Germany.head()
# Out:
#     sofifa_id                                         player_url  \
# 7      167495  https://sofifa.com/player/167495/manuel-neuer/...
# 8      192448  https://sofifa.com/player/192448/marc-andre-te...
# 19     212622  https://sofifa.com/player/212622/joshua-kimmic...
# 24     182521  https://sofifa.com/player/182521/toni-kroos/22...
# 35     189596  https://sofifa.com/player/189596/thomas-muller...
#
#        short_name              long_name player_positions  overall  potential  \
# 7        M. Neuer     Manuel Peter Neuer               GK       90         90
# 8   M. ter Stegen  Marc-André ter Stegen               GK       90         92
# 19     J. Kimmich  Joshua Walter Kimmich          CDM, RB       89         90
# 24       T. Kroos             Toni Kroos               CM       88         88
# 35      T. Müller          Thomas Müller      CAM, RM, RW       87         87
#
#       value_eur  wage_eur  age  ...   lcb    cb   rcb    rb    gk  \
# ...

# %% [markdown]
# # Sorting the players in the descending order of their height

# %%
Germany.sort_values(by=['height_cm'],ascending=False).head()
# Out:
#        sofifa_id                                         player_url  \
# 15084     262899  https://sofifa.com/player/262899/cottrell-ezek...
# 16695     253410  https://sofifa.com/player/253410/jonas-hupe/22...
# 10463     236831  https://sofifa.com/player/236831/aaron-seydel/...
# 2064      199833  https://sofifa.com/player/199833/lars-unnersta...
# 18284     259089  https://sofifa.com/player/259089/marc-richter/...
#
#           short_name                 long_name player_positions  overall  \
# 15084     C. Ezekwem          Cottrell Ezekwem               CB       61
# 16695        J. Hupe                Jonas Hupe               GK       58
# 10463      A. Seydel              Aaron Seydel      ST, LM, CAM       65
# 2064   L. Unnerstall           Lars Unnerstall               GK       74
# 18284     M. Richter  Marc Paul Victor Richter               GK       54
#
#        potential  value_eur  wage_eur  age  ...   lcb    cb   rcb    rb    gk  \
# ...

# %% [markdown]
# # Sorting the players in the descending order of their weight

# %%
Germany.sort_values(by=['weight_kg'],ascending=False).head()
# Out:
#        sofifa_id                                         player_url  \
# 13773     239746  https://sofifa.com/player/239746/lukas-watkowi...
# 2064      199833  https://sofifa.com/player/199833/lars-unnersta...
# 3846      158777  https://sofifa.com/player/158777/philipp-tscha...
# 244       212190  https://sofifa.com/player/212190/niklas-sule/2...
# 759       213331  https://sofifa.com/player/213331/jonathan-tah/...
#
#           short_name          long_name player_positions  overall  potential  \
# 13773   L. Watkowiak    Lukas Watkowiak               GK       62         67
# 2064   L. Unnerstall    Lars Unnerstall               GK       74         74
# 3846    P. Tschauner  Philipp Tschauner               GK       71         71
# 244          N. Süle        Niklas Süle           CB, RB       82         87
# 759           J. Tah       Jonathan Tah               CB       78         82
#
#         value_eur  wage_eur  age  ...   lcb    cb   rcb    rb    gk  \
# ...

# %% [markdown]
# # Sorting the players in descending order of their salaries

# %%
Germany.sort_values(by=['wage_eur'],ascending=False).head()
# Out:
#      sofifa_id                                         player_url  \
# 24      182521  https://sofifa.com/player/182521/toni-kroos/22...
# 8       192448  https://sofifa.com/player/192448/marc-andre-te...
# 78      186942  https://sofifa.com/player/186942/ilkay-gundoga...
# 19      212622  https://sofifa.com/player/212622/joshua-kimmic...
# 126     212188  https://sofifa.com/player/212188/timo-werner/2...
#
#         short_name              long_name player_positions  overall  \
# 24        T. Kroos             Toni Kroos               CM       88
# 8    M. ter Stegen  Marc-André ter Stegen               GK       90
# 78     İ. Gündoğan         İlkay Gündoğan          CM, CDM       85
# 19      J. Kimmich  Joshua Walter Kimmich          CDM, RB       89
# 126      T. Werner            Timo Werner           ST, LW       84
#
#      potential    value_eur  wage_eur  age  ...   lcb    cb   rcb    rb    gk  \
# ...

# %%
Germany[['short_name','wage_eur']].sort_values(by=['wage_eur'],ascending=False).head()
# Out:
#         short_name  wage_eur
# 24        T. Kroos  310000.0
# 8    M. ter Stegen  250000.0
# 78     İ. Gündoğan  185000.0
# 19      J. Kimmich  160000.0
# 126      T. Werner  155000.0

# %% [markdown]
# # Shooting

# %%
player_shooting=fifa[['short_name','shooting']]

# %% [markdown]
# # Top 5 players with best shooting skills

# %%
player_shooting.sort_values(by=['shooting'],ascending=False).head()
# Out:
#            short_name  shooting
# 2   Cristiano Ronaldo      94.0
# 0            L. Messi      92.0
# 1      R. Lewandowski      92.0
# 29         E. Haaland      91.0
# 9             H. Kane      91.0

# %% [markdown]
# # Defending

# %%
player_defending=fifa[['short_name','defending','nationality_name']]

# %% [markdown]
# # Top 5 players with best defending skills

# %%
player_defending.sort_values(by=['defending'],ascending=False).head()
# Out:
#       short_name  defending nationality_name
# 15   V. van Dijk       91.0      Netherlands
# 49    M. Hummels       89.0          Germany
# 47  G. Chiellini       89.0            Italy
# 39    Marquinhos       89.0           Brazil
# 46    Rúben Dias       88.0         Portugal

# %% [markdown]
# # Thank You
